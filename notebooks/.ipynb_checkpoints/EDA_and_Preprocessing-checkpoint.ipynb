# %%
import pandas as pd             
import numpy as np              
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv('../data/cardio_train.csv', sep=';')

df.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
print(f"Shape of dataset: {df.shape}")
print("-" * 30)
df.info()
# Out:
# Shape of dataset: (70000, 13)
# ------------------------------
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70000 entries, 0 to 69999
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           70000 non-null  int64
#  1   age          70000 non-null  int64
#  2   gender       70000 non-null  int64
#  3   height       70000 non-null  int64
#  4   weight       70000 non-null  float64
#  5   ap_hi        70000 non-null  int64
#  6   ap_lo        70000 non-null  int64
#  7   cholesterol  70000 non-null  int64
#  8   gluc         70000 non-null  int64
#  9   smoke        70000 non-null  int64
#  10  alco         70000 non-null  int64
#  11  active       70000 non-null  int64
#  12  cardio       70000 non-null  int64
# dtypes: float64(1), int64(12)
# memory usage: 6.9 MB

# %%
print("Missing values per column:")
print(df.isnull().sum()) 

print("-" * 30)

duplicates = df.duplicated().sum()
print(f"Number of duplicate rows: {duplicates}")

if duplicates > 0:
    df.drop_duplicates(inplace=True)
    print("Duplicates removed!")
# Out:
# Missing values per column:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_lo          0
# cholesterol    0
# gluc           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64
# ------------------------------
# Number of duplicate rows: 0

# %%
df['age_years'] = (df['age'] / 365).round().astype(int)

df.drop(columns=['age', 'id'], inplace=True)

df.head()
# Out:
#    gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  alco  \
# 0       2     168    62.0    110     80            1     1      0     0
# 1       1     156    85.0    140     90            3     1      0     0
# 2       1     165    64.0    130     70            3     1      0     0
# 3       2     169    82.0    150    100            1     1      0     0
# 4       1     156    56.0    100     60            1     1      0     0
#
#    active  cardio  age_years
# 0       1       0         50
# 1       1       1         55
# 2       0       1         52
# 3       1       1         48
# 4       0       0         48

# %%
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.boxplot(x=df['height'])
plt.title('Height Distribution')

plt.subplot(1, 2, 2)
sns.boxplot(x=df['weight'])
plt.title('Weight Distribution')
plt.show()

# %% [markdown]
# ## (Removing the "Impossible" Data)
# ### Note: We are using standard medical logic here. Blood pressure (ap_hi, ap_lo) cannot be negative or absurdly high (e.g., > 250).

# %%
df = df[(df['height'] >= 100) & (df['height'] <= 250)]

# Keep weights above 30kg
df = df[df['weight'] >= 30]

# Filter Blood Pressure: Systolic (ap_hi) must be > Diastolic (ap_lo)
# Also removing impossible extreme values (e.g., negative BP)
df = df[(df['ap_hi'] < 250) & (df['ap_hi'] > 40)]
df = df[(df['ap_lo'] < 200) & (df['ap_lo'] > 40)]

print(f"Dataset shape after cleaning: {df.shape}")
# Out:
# Dataset shape after cleaning: (68727, 12)

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap')
plt.show()

# %%
sns.countplot(x='cardio', data=df)
plt.title('Distribution of Target Variable (0=Healthy, 1=Disease)')
plt.show()

# %%
# We generally don't scale the target 'cardio' or binary columns like 'gender'
cols_to_scale = ['height', 'weight', 'ap_hi', 'ap_lo', 'age_years']

for col in cols_to_scale:
    df[col] = (df[col] - df[col].min()) / (df[col].max() - df[col].min())

df.to_csv('../data/cardio_train_clean.csv', index=False)
print("Cleaned data saved as 'cardio_train_clean.csv'")
df.head()
# Out:
# Cleaned data saved as 'cardio_train_clean.csv'
#    gender    height    weight     ap_hi     ap_lo  cholesterol  gluc  smoke  \
# 0       2  0.453333  0.188235  0.235294  0.241379            1     1      0
# 1       1  0.373333  0.323529  0.411765  0.310345            3     1      0
# 2       1  0.433333  0.200000  0.352941  0.172414            3     1      0
# 3       2  0.460000  0.305882  0.470588  0.379310            1     1      0
# 4       1  0.373333  0.152941  0.176471  0.103448            1     1      0
#
#    alco  active  cardio  age_years
# 0     0       1       0   0.571429
# 1     0       1       1   0.714286
# 2     0       0       1   0.628571
# 3     0       1       1   0.514286
# 4     0       0       0   0.514286
